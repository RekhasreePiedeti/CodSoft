# %% [markdown]
# <a href="https://colab.research.google.com/github/RekhasreePiedeti/CodSoft/blob/main/CONTACTBOOK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# Function to load contacts from a JSON file
def load_contacts():
    try:
        with open("contacts.json", "r") as file:
            contacts = json.load(file)
    except FileNotFoundError:
        contacts = []
    return contacts

# Function to save contacts to a JSON file
def save_contacts(contacts):
    with open("contacts.json", "w") as file:
        json.dump(contacts, file, indent=2)

# Function to add a new contact
def add_contact():
    name = input("Enter the contact's name: ")
    phone = input("Enter the contact's phone number: ")
    email = input("Enter the contact's email: ")
    address = input("Enter the contact's address: ")

    new_contact = {
        "Name": name,
        "Phone": phone,
        "Email": email,
        "Address": address
    }

    contacts.append(new_contact)
    save_contacts(contacts)
    print("Contact added successfully!")

# Function to view all contacts
def view_contacts():
    if not contacts:
        print("No contacts found.")
    else:
        for i, contact in enumerate(contacts, start=1):
            print(f"\nContact {i}:")
            print(f"Name: {contact['Name']}")
            print(f"Phone: {contact['Phone']}")
            print(f"Email: {contact['Email']}")
            print(f"Address: {contact['Address']}")

# Function to search for a contact by name or phone number
def search_contact():
    search_term = input("Enter the name or phone number to search for: ")
    found_contacts = []

    for contact in contacts:
        if search_term in contact['Name'] or search_term in contact['Phone']:
            found_contacts.append(contact)

    if found_contacts:
        print("\nFound Contacts:")
        for i, contact in enumerate(found_contacts, start=1):
            print(f"Contact {i}:")
            print(f"Name: {contact['Name']}")
            print(f"Phone: {contact['Phone']}")
            print(f"Email: {contact['Email']}")
            print(f"Address: {contact['Address']}")
    else:
        print("No matching contacts found.")

# Function to update a contact
def update_contact():
    search_term = input("Enter the name of the contact to update: ")
    for contact in contacts:
        if search_term == contact['Name']:
            contact['Phone'] = input("Enter the new phone number: ")
            contact['Email'] = input("Enter the new email: ")
            contact['Address'] = input("Enter the new address: ")
            save_contacts(contacts)
            print("Contact updated successfully!")
            return
    print("Contact not found.")

# Function to delete a contact
def delete_contact():
    search_term = input("Enter the name of the contact to delete: ")
    for contact in contacts:
        if search_term == contact['Name']:
            contacts.remove(contact)
            save_contacts(contacts)
            print("Contact deleted successfully!")
            return
    print("Contact not found.")

if __name__ == "__main__":
    contacts = load_contacts()

    while True:
        print("\nContact Book Menu:")
        print("1. Add Contact")
        print("2. View Contacts")
        print("3. Search Contact")
        print("4. Update Contact")
        print("5. Delete Contact")
        print("6. Exit")

        choice = input("Enter your choice (1/2/3/4/5/6): ")

        if choice == "1":
            add_contact()
        elif choice == "2":
            view_contacts()
        elif choice == "3":
            search_contact()
        elif choice == "4":
            update_contact()
        elif choice == "5":
            delete_contact()
        elif choice == "6":
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please select a valid option.")
# Out:
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 1
# Enter the contact's name: dad
# Enter the contact's phone number: 1234561123
# Enter the contact's email: dad@gmail.com
# Enter the contact's address: home1
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 1
# Enter the contact's name: mom
# Enter the contact's phone number: 7894561231
# Enter the contact's email: mom@gmail.com
# Enter the contact's address: home2
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 1
# Enter the contact's name: sissy
# Enter the contact's phone number: 4567891231
# Enter the contact's email: sissy@gmail.com
# Enter the contact's address: home1
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 2
#
# Contact 1:
# Name: dad
# Phone: 1234561123
# Email: dad@gmail.com
# Address: home1
#
# Contact 2:
# Name: mom
# Phone: 7894561231
# Email: mom@gmail.com
# Address: home2
#
# Contact 3:
# Name: sissy
# Phone: 4567891231
# Email: sissy@gmail.com
# Address: home1
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 3
# Enter the name or phone number to search for: mom
#
# Found Contacts:
# Contact 1:
# Name: mom
# Phone: 7894561231
# Email: mom@gmail.com
# Address: home2
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 4
# Enter the name of the contact to update: mom
# Enter the new phone number: 4567896598
# Enter the new email: mom@gmail.com
# Enter the new address: home1
# Contact updated successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 2
#
# Contact 1:
# Name: dad
# Phone: 1234561123
# Email: dad@gmail.com
# Address: home1
#
# Contact 2:
# Name: mom
# Phone: 4567896598
# Email: mom@gmail.com
# Address: home1
#
# Contact 3:
# Name: sissy
# Phone: 4567891231
# Email: sissy@gmail.com
# Address: home1
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 5
# Enter the name of the contact to delete: sissy
# Contact deleted successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 2
#
# Contact 1:
# Name: dad
# Phone: 1234561123
# Email: dad@gmail.com
# Address: home1
#
# Contact 2:
# Name: mom
# Phone: 4567896598
# Email: mom@gmail.com
# Address: home1
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1/2/3/4/5/6): 6
# Exiting...
