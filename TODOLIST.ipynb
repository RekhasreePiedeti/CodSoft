# %% [markdown]
# <a href="https://colab.research.google.com/github/RekhasreePiedeti/CodSoft/blob/main/TODOLIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Initialize an empty list to store tasks
tasks = []

# Function to display the menu
def display_menu():
    print("\nTodo List Application")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Mark Task as Completed")
    print("4. Remove Task")
    print("5. Exit")

# Function to add a task
def add_task():
    task = input("\nEnter a new task: ")
    tasks.append({"task": task, "completed": False})
    print("Task added successfully!")

# Function to view all tasks
def view_tasks():
    if not tasks:
        print("No tasks found.")
    else:
        print("\nTask List:")
        for index, task in enumerate(tasks, start=1):
            status = "Completed" if task["completed"] else "Not Completed"
            print(f"{index}. {task['task']} - {status}")

# Function to mark a task as completed
def mark_completed():
    view_tasks()
    try:
        task_index = int(input("\nEnter the task number to mark as completed: ")) - 1
        if 0 <= task_index < len(tasks):
            tasks[task_index]["completed"] = True
            print("Task marked as completed!")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Invalid input. Please enter a valid task number.")

# Function to remove a task
def remove_task():
    view_tasks()
    try:
        task_index = int(input("\nEnter the task number to remove: ")) - 1
        if 0 <= task_index < len(tasks):
            removed_task = tasks.pop(task_index)
            print(f"Task '{removed_task['task']}' removed successfully!")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Invalid input. Please enter a valid task number.")

# Main loop
while True:
    display_menu()
    choice = input("Enter your choice (1/2/3/4/5): ")

    if choice == "1":
        add_task()
    elif choice == "2":
        view_tasks()
    elif choice == "3":
        mark_completed()
    elif choice == "4":
        remove_task()
    elif choice == "5":
        print("Exiting...")
        break
    else:
        print("Invalid choice. Please select a valid option.")

# Save tasks to a file
with open("tasks.txt", "w") as file:
    for task in tasks:
        file.write(f"{task['task']}|{task['completed']}\n")
ki
# Out:
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 1
#
# Enter a new task: writing
# Task added successfully!
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 1
#
# Enter a new task: reading
# Task added successfully!
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 3
#
# Task List:
# 1. writing - Not Completed
# 2. reading - Not Completed
#
# Enter the task number to mark as completed: kicking
# Invalid input. Please enter a valid task number.
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 2
#
# Task List:
# 1. writing - Not Completed
# 2. reading - Not Completed
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 1
#
# Enter a new task: kicking
# Task added successfully!
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 2
#
# Task List:
# 1. writing - Not Completed
# 2. reading - Not Completed
# 3. kicking - Not Completed
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 3
#
# Task List:
# 1. writing - Not Completed
# 2. reading - Not Completed
# 3. kicking - Not Completed
#
# Enter the task number to mark as completed: 1
# Task marked as completed!
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5):
# Invalid choice. Please select a valid option.
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 3
#
# Task List:
# 1. writing - Completed
# 2. reading - Not Completed
# 3. kicking - Not Completed
#
# Enter the task number to mark as completed: 2
# Task marked as completed!
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 2
#
# Task List:
# 1. writing - Completed
# 2. reading - Completed
# 3. kicking - Not Completed
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 4
#
# Task List:
# 1. writing - Completed
# 2. reading - Completed
# 3. kicking - Not Completed
#
# Enter the task number to remove: 3
# Task 'kicking' removed successfully!
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 2
#
# Task List:
# 1. writing - Completed
# 2. reading - Completed
#
# Todo List Application
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1/2/3/4/5): 5
# Exiting...
